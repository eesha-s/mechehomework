# %%
import math
import matplotlib.pyplot as plt
#initial conditions

def make_particle(theta_value):
  m=0.01
  g=9.8
  v0=10
  theta=(theta_value/180)*math.pi
  x0=0
  y0=0
  c1=0.001
  time=0
  time_step=0.1
  v0_x=v0*math.cos(theta)
  v0_y=v0*math.sin(theta)
  x_positions=[x0]
  y_positions=[y0]
  for i in range(15):
  #first find acceleration
    time=time+time_step
    ax=(-1*c1*v0*v0_x)/m
    ay=(-1*g)-(c1*v0*v0_y)/m

    #update velocity
    vx_new=v0_x+ax*time_step
    vy_new=v0_y+ay*time_step
    x_new=x0+vx_new*time_step
    y_new=y0+vy_new*time_step

    v0_x=vx_new
    v0_y=vy_new
    x0=x_new
    y0=y_new
    x_positions.append(x0)
    y_positions.append(y0)
    v0=math.sqrt(v0_x**2+v0_y**2)
  return x_positions,y_positions

plt.figure()
for i in range(1,9):


  x,y=make_particle(20*i)
  plt.plot(x,y,markersize=2,label=f"{20*i}°")

plt.xlabel('x position')
plt.ylabel('y position')
plt.title("Projectile Motion for c=0.001")
plt.legend()
plt.grid()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
#initial conditions

def make_particle(theta_value):
  m=0.01
  g=9.8
  v0=10
  theta=(theta_value/180)*math.pi
  x0=0
  y0=0
  c1=0.01
  time=0
  time_step=0.1
  v0_x=v0*math.cos(theta)
  v0_y=v0*math.sin(theta)
  x_positions=[x0]
  y_positions=[y0]
  for i in range(15):
  #first find acceleration
    time=time+time_step
    ax=(-1*c1*v0*v0_x)/m
    ay=(-1*g)-(c1*v0*v0_y)/m

    #update velocity
    vx_new=v0_x+ax*time_step
    vy_new=v0_y+ay*time_step
    x_new=x0+vx_new*time_step
    y_new=y0+vy_new*time_step

    v0_x=vx_new
    v0_y=vy_new
    x0=x_new
    y0=y_new
    x_positions.append(x0)
    y_positions.append(y0)
    v0=math.sqrt(v0_x**2+v0_y**2)
  return x_positions,y_positions

plt.figure()
for i in range(1,9):


  x,y=make_particle(20*i)
  plt.plot(x,y,markersize=2,label=f"{20*i}°")

plt.xlabel('x position')
plt.ylabel('y position')
plt.title("Projectile Motion for c=0.01")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# as we can see from the above two plots, the increase in drag has a significant effect on the motion of the particles. when we increase drag by a factor of ten, the particles barely move in the x direction and are pulled very rapidly downward.
